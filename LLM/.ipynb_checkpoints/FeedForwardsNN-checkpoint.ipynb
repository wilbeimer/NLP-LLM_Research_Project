# %%
import numpy as np
import pandas as pd
from math import sqrt

# %%
COL_NAMES = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "name"]
             
auto = pd.read_csv("auto+mpg/auto-mpg.data", sep='\s+', names=COL_NAMES)

# %%
auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg = auto["mpg"]
auto = auto.drop(columns=["mpg"])
train = auto.sample(frac=0.8)
test = auto.drop(train.index)

# %%
class FFNN:
    def __init__(self, X: pd.DataFrame, n_h1, n_out):
        self.X = X
        self.W1, self.W2 = FFNN.initialize_weights(len(X.columns), n_h1, n_out)

    def forward(self):
        output1 = []
        output2 = []
        
        print("W1:", type(self.W1))
        print("X:",type(self.X.to_numpy()))

        output1 = FFNN.relu(self.X.to_numpy() @ self.W1)
                
        output2 = FFNN.sigmoid(output1 @ self.W2)

        return output2

    @staticmethod
    def initialize_weights(n_in, n_h1, n_out):
        Var = 2/(n_in + n_out)
        std = math.sqrt(Var)

        w1 = np.random.normal(loc=0, scale=std, size= (n_in, n_h1))
        w2 = np.random.normal(loc=0, scale=std, size= (n_h1, n_out))
        return w1, w2
        

    @staticmethod
    def relu(x):
        return max(0,x)

    @staticmethod
    def sigmoid(x):
        return 1/(1+(e ** (-x)))

# %%
nn = FFNN(auto, 2, 1)
nn.forward()
# Out:
# W1: <class 'numpy.ndarray'>
# X: <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[168], line 2
#       1 nn = FFNN(auto, 2, 1)
# ----> 2 nn.forward()
#
# Cell In[167], line 13, in FFNN.forward(self)
#      10 print("W1:", type(self.W1))
#      11 print("X:",type(self.X.to_numpy()))
# ---> 13 sum1 = self.X.to_numpy() @ self.W1
#      14 output1 = FFNN.relu(sum1)
#      16 output2 = FFNN.sigmoid(output1 @ self.W2)
#
# TypeError: can't multiply sequence by non-int of type 'float'
